# %% [markdown]
# # Bokeh
#
# ## Bokeh is a library for interactive visualizations in Python.

# %%
import bokeh
import pandas as pd
#from vega_datasets import data

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="800317ff-662c-4b65-af38-9a2c38b8ada3">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show
from bokeh.plotting import figure

# %%
#gapminder = pd.DataFrame(data.gapminder())
gapminder = gapminder_life_expectancy.csv
gapminder.head()
# Out:
#    cluster      country  fertility  life_expect       pop  year
# 0        0  Afghanistan        7.7       30.332   8891209  1955
# 1        0  Afghanistan        7.7       31.997   9829450  1960
# 2        0  Afghanistan        7.7       34.020  10997885  1965
# 3        0  Afghanistan        7.7       36.088  12430623  1970
# 4        0  Afghanistan        7.7       38.438  14132019  1975

# %%
gapminder.loc[gapminder['year'] == 2000].head()
# Out:
#     cluster      country  fertility  life_expect       pop  year
# 9         0  Afghanistan     7.4792       42.129  23898198  2000
# 20        3    Argentina     2.3500       74.340  37497728  2000
# 31        3        Aruba     2.1240       73.451     69539  2000
# 42        4    Australia     1.7560       80.370  19164620  2000
# 53        1      Austria     1.3820       78.980   8113413  2000

# %% [markdown]
# ## Lets plot fertility on the x axis and life expectancy on the y axis

# %%
fertility = gapminder.loc[gapminder['year'] == 2000]['fertility']
life = gapminder.loc[gapminder['year'] == 2000]['life_expect']

grph = figure(height = 200)
grph.circle(x = fertility, y = life) # try cross, change color
show(grph)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="918c9400-4c7e-4daa-9f6a-3a0c084a064f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("918c9400-4c7e-4daa-9f6a-3a0c084a064f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("918c9400-4c7e-4daa-9f6a-3a0c084a064f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '918c9400-4c7e-4daa-9f6a-3a0c084a064f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2be8a38b-7999-46e3-b035-f9070fc7f558":{"roots":{"references":[{"attributes":{},"id":"6a6b366a-faac-4b15-a557-1dd7ce4f2881","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"6642d320-f0ff-4570-bdd6-5daa546e0552","type":"DataRange1d"},{"attributes":{},"id":"8e18ff9d-9640-4634-a748-36ba8339ccfb","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[63]},"y":{"__ndarray__":"...","dtype":"float64","shape":[63]}}},"id":"9674ec9f-2b93-487f-ba92-f54365621a7a","type":"ColumnDataSource"},{"attributes":{},"id":"2b4f333f-0d8b-4f4a-94ca-c796d8f4d6c1","type":"ResetTool"},{"attributes":{"data_source":{"id":"9674ec9f-2b93-487f-ba92-f54365621a7a","type":"ColumnDataSource"},"glyph":{"id":"8544a045-80aa-4c89-9603-afe3d3e8b030","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8532df8a-b942-47cc-8411-d590d15124bd","type":"Circle"},"selection_glyph":null,"view":{"id":"02656bc9-af46-4de7-bf05-cff38a99ef16","type":"CDSView"}},"id":"32abd1a9-b839-4899-8621-04f5ec85b2d9","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5ee55b88-49a9-4e4e-8f0b-4089326e9ff3","type":"BoxAnnotation"},{"attributes":{},"id":"7cfface1-3103-4c89-9010-939d26386a5e","type":"SaveTool"},{"attributes":{"source":{"id":"9674ec9f-2b93-487f-ba92-f54365621a7a","type":"ColumnDataSource"}},"id":"02656bc9-af46-4de7-bf05-cff38a99ef16","type":"CDSView"},{"attributes":{},"id":"927c6ca2-21cb-4760-aed4-eb6076ec8af2","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"5ee55b88-49a9-4e4e-8f0b-4089326e9ff3","type":"BoxAnnotation"}},"id":"53fc4a6e-03d2-4ab8-a046-9e63897827ae","type":"BoxZoomTool"},{"attributes":{},"id":"ddaa81bd-8fce-4257-8480-256a9e609227","type":"BasicTicker"},{"attributes":{"callback":null},"id":"28cbd8f5-de88-4ba9-b83b-3194f0f047d0","type":"DataRange1d"},{"attributes":{"plot":{"id":"83dc574d-cf47-4c22-9be5-8c49c160a113","subtype":"Figure","type":"Plot"},"ticker":{"id":"ddaa81bd-8fce-4257-8480-256a9e609227","type":"BasicTicker"}},"id":"765cf929-0995-4222-bebc-79c267d5820e","type":"Grid"},{"attributes":{},"id":"a0f4cb43-0067-4c21-84dd-523b4d9dbce0","type":"BasicTicker"},{"attributes":{},"id":"6558b8cf-3a5a-4ae9-b5e0-622e6caa5947","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2fc25ff1-0908-41f9-b009-3eac83700362","type":"PanTool"},{"id":"13a617c3-1dbf-46a9-9f85-0a88e0c02aea","type":"WheelZoomTool"},{"id":"53fc4a6e-03d2-4ab8-a046-9e63897827ae","type":"BoxZoomTool"},{"id":"7cfface1-3103-4c89-9010-939d26386a5e","type":"SaveTool"},{"id":"2b4f333f-0d8b-4f4a-94ca-c796d8f4d6c1","type":"ResetTool"},{"id":"9dae0901-e25f-4187-ab43-72d42672b54b","type":"HelpTool"}]},"id":"59e0da40-1bd5-4f06-93f6-ccc76a37ae2d","type":"Toolbar"},{"attributes":{"below":[{"id":"8a78c6cf-9789-48d5-bdd1-d3d12d149529","type":"LinearAxis"}],"left":[{"id":"70843aa4-75e9-4e9a-ab75-0c36e30f652c","type":"LinearAxis"}],"plot_height":200,"renderers":[{"id":"8a78c6cf-9789-48d5-bdd1-d3d12d149529","type":"LinearAxis"},{"id":"765cf929-0995-4222-bebc-79c267d5820e","type":"Grid"},{"id":"70843aa4-75e9-4e9a-ab75-0c36e30f652c","type":"LinearAxis"},{"id":"96c6aefe-e89b-4662-bec5-f7b58952b31a","type":"Grid"},{"id":"5ee55b88-49a9-4e4e-8f0b-4089326e9ff3","type":"BoxAnnotation"},{"id":"32abd1a9-b839-4899-8621-04f5ec85b2d9","type":"GlyphRenderer"}],"title":{"id":"15c3bd27-c20a-45c3-90da-f13dce9ac66e","type":"Title"},"toolbar":{"id":"59e0da40-1bd5-4f06-93f6-ccc76a37ae2d","type":"Toolbar"},"x_range":{"id":"28cbd8f5-de88-4ba9-b83b-3194f0f047d0","type":"DataRange1d"},"x_scale":{"id" ...

# %% [markdown]
# ### The ColumnDataSource is the core of most Bokeh plots, providing the data that is visualized by the glyphs of the plot.  It's a mapping between column names and lists of data. The ColumnDataSource takes a data parameter which is a dict, with string column names as keys and lists (or arrays) of data values as values.
