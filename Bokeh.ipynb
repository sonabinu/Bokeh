# %% [markdown]
# # Bokeh
#
# ## Bokeh is a library for interactive visualizations in Python.
#
# website : https://bokeh.pydata.org/en/latest/

# %%
import bokeh
import pandas as pd
from vega_datasets import data

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d77c3bc2-4685-435a-aba6-c1cfcf6a3dfb">Loading BokehJS ...</span>
#     </div>

# %%
gapminder = pd.DataFrame(data.gapminder())
gapminder.head()
# Out:
#    cluster      country  fertility  life_expect       pop  year
# 0        0  Afghanistan        7.7       30.332   8891209  1955
# 1        0  Afghanistan        7.7       31.997   9829450  1960
# 2        0  Afghanistan        7.7       34.020  10997885  1965
# 3        0  Afghanistan        7.7       36.088  12430623  1970
# 4        0  Afghanistan        7.7       38.438  14132019  1975

# %%
gapminder.loc[gapminder['year'] == 2000].head()
# Out:
#     cluster      country  fertility  life_expect       pop  year
# 9         0  Afghanistan     7.4792       42.129  23898198  2000
# 20        3    Argentina     2.3500       74.340  37497728  2000
# 31        3        Aruba     2.1240       73.451     69539  2000
# 42        4    Australia     1.7560       80.370  19164620  2000
# 53        1      Austria     1.3820       78.980   8113413  2000

# %% [markdown]
# Lets plot fertility on the x axis and life expectancy on the y axis

# %%
fertility = gapminder.loc[gapminder['year'] == 2000]['fertility']
life = gapminder.loc[gapminder['year'] == 2000]['life_expect']

grph = figure() # can adjust height
grph.circle(x = fertility, y = life) # try cross, change color
show(grph)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f7b02803-ffaa-4abe-82e6-b611ef66f951"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f7b02803-ffaa-4abe-82e6-b611ef66f951");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f7b02803-ffaa-4abe-82e6-b611ef66f951");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f7b02803-ffaa-4abe-82e6-b611ef66f951' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cbcc65cc-1e95-4076-adf6-ff2eff6c8951":{"roots":{"references":[{"attributes":{},"id":"33a0ffe8-c9f3-4f88-ac00-4cb019d23bd6","type":"ResetTool"},{"attributes":{"below":[{"id":"5ddcc279-4a30-4d4d-ac73-f4ebd33cfe56","type":"LinearAxis"}],"left":[{"id":"a8c13e37-2504-49cd-95f8-6d0df384b771","type":"LinearAxis"}],"renderers":[{"id":"5ddcc279-4a30-4d4d-ac73-f4ebd33cfe56","type":"LinearAxis"},{"id":"aa91a098-a7e5-4133-8d58-a140659c4432","type":"Grid"},{"id":"a8c13e37-2504-49cd-95f8-6d0df384b771","type":"LinearAxis"},{"id":"69b2f498-7116-4f33-9ded-c4c887474adc","type":"Grid"},{"id":"e409f3e3-22ab-4ad2-aacd-3b0fbdbb4ccf","type":"BoxAnnotation"},{"id":"65d0de3b-1b3c-4a50-9bc1-0d35c17f16a8","type":"GlyphRenderer"}],"title":{"id":"384e0e41-08d4-46f1-bfae-c9460264c89f","type":"Title"},"toolbar":{"id":"4ffc70ed-0c94-4495-9b36-785f57399949","type":"Toolbar"},"x_range":{"id":"e2daa04a-b081-439e-a48f-c025eee5fb79","type":"DataRange1d"},"x_scale":{"id":"0b83be56-d6f5-478b-8805-a2b8f67f46ab","type":"LinearScale"},"y_range":{"id":"6a46d760-5851-4052-b020-718ae65796f8","type":"DataRange1d"},"y_scale":{"id":"2b682711-9cac-4420-a123-4189259434be","type":"LinearScale"}},"id":"23d6a71c-1435-4043-a7b4-31141c3d5ee6","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"e2daa04a-b081-439e-a48f-c025eee5fb79","type":"DataRange1d"},{"attributes":{},"id":"dd2e8b6d-de8f-442b-aab1-d10184043d87","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e409f3e3-22ab-4ad2-aacd-3b0fbdbb4ccf","type":"BoxAnnotation"},{"attributes":{"source":{"id":"f7ecb07e-fef9-4e3d-879c-bcfbba396c2b","type":"ColumnDataSource"}},"id":"e6f834ee-6edd-4293-acc8-97f727271631","type":"CDSView"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"29824259-df00-4a19-94e8-fddbf421aa3d","type":"PanTool"},{"id":"fa7c279f-939c-4bfe-b2a1-3a1d3046ca11","type":"WheelZoomTool"},{"id":"61dae67c-9306-4a9b-ac9f-de2a1cb38ccb","type":"BoxZoomTool"},{"id":"1028beb4-494e-40b7-88f2-9b699f5d8cfa","type":"SaveTool"},{"id":"33a0ffe8-c9f3-4f88-ac00-4cb019d23bd6","type":"ResetTool"},{"id":"41eac32d-00ea-4192-88b2-2134465a34db","type":"HelpTool"}]},"id":"4ffc70ed-0c94-4495-9b36-785f57399949","type":"Toolbar"},{"attributes":{},"id":"29824259-df00-4a19-94e8-fddbf421aa3d","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[63]},"y":{"__ndarray__":"...","dtype":"float64","shape":[63]}}},"id":"f7ecb07e-fef9-4e3d-879c-bcfbba396c2b","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"384e0e41-08d4-46f1-bfae-c9460264c89f","type":"Title"},{"attributes":{},"id":"2b682711-9cac-4420-a123-4189259434be","type":"LinearScale"},{"attributes":{},"id":"0b83be56-d6f5-478b-8805-a2b8f67f46ab","type":"LinearScale"},{"attributes":{},"id":"1028beb4-494e-40b7-88f2-9b699f5d8cfa","type":"SaveTool"},{"attributes":{"callback":null},"id":"6a46d760-5851-4052-b020-718ae65796f8","type":"DataRange1d"},{"attributes":{},"id":"199819d1-3138-42d9-a4cd-f4f4c29aaeef","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"e409f3e3-22ab-4ad2-aacd-3b0fbdbb4ccf","type":"BoxAnnotation"}},"id":"61dae67c-9306-4a9b-ac9f-de2a1cb38ccb","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c30fa9ff-9592-47f0-964b-cf546cd480cb","type":"Circle"},{"attributes":{"plot":{"id":"23d6a71c-1435-4043-a7b4-31141c3d5ee6","subtype":"Figure","type":"Plot"},"ticker":{"id":"04801ea1-0bf7-402a-9d7e-46073045bbcb","type":"BasicTi ...

# %% [markdown]
# The ColumnDataSource is the core of most Bokeh plots, providing the data that is visualized by the glyphs of the plot.  It's a mapping between column names and lists of data. The ColumnDataSource takes a data parameter which is a dict, with string column names as keys and lists (or arrays) of data values as values.

# %%
from bokeh.models import ColumnDataSource

# %%
country = gapminder.loc[gapminder['year'] == 2000]['country']

# %%
source = ColumnDataSource(dict(x=fertility,y=life, country = country))
#print(source.column_names)
#source.data

# %%
grph.circle(x = 'x', y = 'y', source =source)
show(grph)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3c7610a9-f664-4f53-a1db-bf5db56cfdc8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3c7610a9-f664-4f53-a1db-bf5db56cfdc8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3c7610a9-f664-4f53-a1db-bf5db56cfdc8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3c7610a9-f664-4f53-a1db-bf5db56cfdc8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0c4474fe-8059-4475-bfcb-86816b62ce8b":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"
subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"e2daa04a-b081-439e-a48f-c025eee5fb79","type":"DataRange1d"},{"attributes":{},"id":"dd2e8b6d-de8f-442b-aab1-d101 ...

# %%
# use other columns in our data

# %%
from bokeh.models import HoverTool

# %%
hover = HoverTool(tooltips = '@country')
grph = figure(tools = [hover], height = 300)
grph.circle(x = 'x', y = 'y', source =source, color = 'teal')
show(grph)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="22b46bbe-eeea-4745-b02e-970fb5aba8b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("22b46bbe-eeea-4745-b02e-970fb5aba8b4");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("22b46bbe-eeea-4745-b02e-970fb5aba8b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '22b46bbe-eeea-4745-b02e-970fb5aba8b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4775ef7c-b7f2-4718-a108-772f71de603d":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"229e0a29-76a4-45e2-bd38-960963bc1a1e","type":"Title"},{"attributes":{"callback":null},"id":"97fd759e-5795-4d32-beb5-1172f271ebb0","type":"DataRange1d"},{"attributes":{},"id":"ad8f9d69-0a95-40d5-b976-9297c197401d","type":"LinearScale"},{"attributes":{"plot":{"id":"615cbd5d-dfcd-4c42-aca2-730e2e8eee2b","subtype":"Figure","type":"Plot"},"ticker":{"id":"9c60d251-5997-46f5-9b49-0f04bb12b6fa","type":"BasicTicker"}},"id":"e56d273e-e9ae-4fee-b9ed-252272a741c1","type":"Grid"},{"attributes":{"source":{"id":"5dcef9ee-4b2d-451d-aa4d-85fbf2cb9471","type":"ColumnDataSource"}},"id":"e3178a24-3896-4a8c-8fd0-b68ec94be25b","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x","y","country"],"data":{"country":["Afghanistan","Argentina","Aruba","Australia","Austria","Bahamas","Bangladesh","Barbados","Belgium","Bolivia","Brazil","Canada","Chile","China","Colombia","Costa Rica","Croatia","Cuba","Dominican Republic","Ecuador","Egypt","El Salvador","Finland","France","Georgia","Germany","Greece","Grenada","Haiti","Hong Kong","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Kenya","South Korea","North Korea","Lebanon","Mexico","Netherlands","New Zealand","Nigeria","Norway","Pakistan","Peru","Philippines","Poland","Portugal","Rwanda","Saudi Arabia","South Africa","Spain","Switzerland","Turkey","United Kingdom","United States","Venezuela"],"x":{"__ndarray__":"...","dtype":"float64","shape":[63]},"y":{"__ndarray__":"...","dtype":"float64","shape":[63]}}},"id":"5dcef9ee-4b2d-451d-aa4d-85fbf2cb9471","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"teal"},"line_color":{"value":"teal"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d9b61fa3-4f01-476a-af72-00bae43b6c21","type":"Circle"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"53891c8e-afc4-4f50-8935-9d7a930a6ec5","type":"HoverTool"}]},"id":"c74ac31a-1400-43ab-93e5-71e23f4c6b57","type":"Toolbar"},{"attributes":{"below":[{"id":"a47558ca-292a-4caf-886a-defa5a5bc3f4","type":"LinearAxis"}],"left":[{"id":"703de3da-f1f4-420d-97de-b501af1328ee","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"a47558ca-292a-4caf-886a-defa5a5bc3f4","type":"LinearAxis"},{"id":"e56d273e-e9ae-4fee-b9ed-252272a741c1","type":"Grid"},{"id":"703de3da-f1f4-420d-97de-b501af1328ee","type":"LinearAxis"},{"id":"936f0cc2-081a-4c27-8258-3bf647b6a5b7","type":"Grid"},{"id":"be282da4-70e0-43bf-9b30-57246aebd086","type":"GlyphRenderer"}],"title":{"id":"229e0a29-76a4-45e2-bd38-960963bc1a1e","type":"Title"},"toolbar":{"id":"c74ac31a-1400-43ab-93e5-71e23f4c6b57","type":"Toolbar"},"x_range":{"id":"3f9bdba3-0b0c-4844-8f0a-665aac738632","type":"DataRange1d"},"x_scale":{"id":"70f90028-fa38-452f-926a-8a6301bf67d9","type":"LinearScale"},"y_range":{"id":"97fd759e-5795-4d32-beb5-1172f271ebb0","type":"DataRange1d"},"y_scale":{"id":"ad8f9d69-0a95-40d5-b976-9297c197401d","type":"LinearScale"}},"id":"615cbd5d-dfcd-4c42-aca2-730e2e8eee2b","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"9c60d251-5997-46f5-9b49-0f04bb12b6fa","type":"BasicTicker"},{"attributes":{},"id":"70f90028-fa38-452f-926a-8a6301bf67d9","type":"LinearScale"},{"attributes":{"formatter":{"id":"ea55d50c-9c4e-4adb-bd26-8f235cea76ff","type":"BasicTickFormatter"},"plot":{"id":"615cbd5d-dfcd-4c42-aca2-730e2e8eee2b","subtype":"Figure","type":"Plot"},"ticker":{"id":"09e6f4e1-9555-4e82-825f-ee1ce14f0df9","type":"BasicTicker"}},"id":"703de3da-f1f4-420d-97de-b501af1328ee","type":"LinearAxis"},{"attributes":{},"id":"ea55d50c-9c4e-4adb-bd26-8f235cea76ff","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"f508dbdb-38bf-4910-b4e9-6130639d1a86","type":"BasicTickFormatter"},"plot":{"id":"615cbd5d-dfcd-4c42-aca2-730e2e8eee2b","subtype":"Figure","type":"Plot"},"ticker":{"id":"9c60d251-5997-46f5-9b49-0f04bb12b6fa ...

# %% [markdown]
# To learn more about configuring plot tools - https://bokeh.pydata.org/en/latest/docs/user_guide/tools.html

# %%
# map the size of the bubble to the population
from bokeh.models import LinearInterpolator

population = gapminder.loc[gapminder['year'] == 2000]['pop']
source = ColumnDataSource(dict(x=fertility,y=life, country = country, size = population))

hover = HoverTool(tooltips = '@country')
grph = figure(tools = [hover], height = 300)

grph.circle(x = 'x', y = 'y', size ='size', source =source, color = 'teal')

show(grph)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d069133e-f569-4eca-b4d0-e9212a6f5b88"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d069133e-f569-4eca-b4d0-e9212a6f5b88");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d069133e-f569-4eca-b4d0-e9212a6f5b88");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd069133e-f569-4eca-b4d0-e9212a6f5b88' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fb0876a7-9ab4-4dc3-b5bc-7a3529616d13":{"roots":{"references":[{"attributes":{},"id":"60795ee3-7177-45f7-ae06-9e6d42af5a6b","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"teal"},"line_color":{"value":"teal"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"326aa113-ebd1-466d-8840-2e226c98957e","type":"Circle"},{"attributes":{"below":[{"id":"d27a5f12-edef-4ad2-bce0-5f2d7481478c","type":"LinearAxis"}],"left":[{"id":"f32bc73e-14fd-4a8f-a5aa-1dcd20e309d2","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":
type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"3f3a9e8e-306d-4bd0-86f4-5b39e0133bdf","type":"BasicTickFormatter"},"plot":{"id":"d7e734e8-e09f-4f00-a075-79e3a1c571ca","subtype":"Figure","type":"Plot"},"ticker":{"id":"f6db615b-cba7-4e7e-819b-118a67672d52","type":"B ...

# %%
# map the size of the bubble to the population
from bokeh.models import LinearInterpolator

hover = HoverTool(tooltips = [('Country','@country'),('Population','@pop'),])

population = gapminder.loc[gapminder['year'] == 2000]['pop']
size_mapper = LinearInterpolator(x = [population.min(), population.max()], y = [5,50])

source = ColumnDataSource(dict(x=fertility,y=life, country = country, population = population))


grph = figure(tools = [hover], height = 300, title = 'Fertility and Life Expectancy')

#can add transparancy with alpha =0.6
grph.circle(x = 'x', y = 'y', size ={'field' : 'population', 'transform' :size_mapper}, alpha =0.6, source =source, color = 'teal') 

show(grph)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="76be7358-f81b-4d08-bca1-7583e096ece4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("76be7358-f81b-4d08-bca1-7583e096ece4");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("76be7358-f81b-4d08-bca1-7583e096ece4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '76be7358-f81b-4d08-bca1-7583e096ece4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"08b6ec4a-e2d4-483e-ad93-bc2603dfad55":{"roots":{"references":[{"attributes":{"callback":null},"id":"1669ae49-a64a-4d62-912d-2aec623ee706","type":"DataRange1d"},{"attributes":{},"id":"7832ce54-bd24-4f0c-8892-5bf6f9fe3cab","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","country","population"],"data":{"country":["Afghanistan","Argentina","Aruba","Australia","Austria","Bahamas","Bangladesh","Barbados","Belgium","Bolivia","Brazil","Canada","Chile","China","Colombia","Costa Rica","Croatia","Cuba","Dominican Republic","Ecuador","Egypt","El Salvador","Finland","France","Georgia","Germany","Greece","Grenada","Haiti","Hong Kong","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Kenya","South Korea","North Korea","Lebanon","Mexico","Netherlands","New Zealand","Nigeria","Norway","Pakistan","Peru","Philippines","Poland","Portugal","Rwanda","Saudi Arabia","South Africa","Spain","Switzerland","Turkey","United Kingdom","United States","Venezuela"],"population":[23898198,37497728,69539,19164620,8113413,290075,130406594,273483,10263618,8152620,175552771,31278097,15153450,1262645000,39685655,3710558,4410830,11134273,8385828,12505204,70492342,6122515,5168595,59381628,4777209,82187909,10559110,89312,7306302,6658720,281043,1007702000,206265000,65660289,22675617,3791690,5842454,57719337,2615467,126699784,29985839,21647682,47351083,3578036,99926620,15907853,3819762,114306700,4492400,146342958,25979722,79739825,38654164,10335597,7507056,23153090,44066197,40016081,7266920,65666677,59522468,282338631,23542649],"x":{"__ndarray__":"...","dtype":"float64","shape":[63]},"y":{"__ndarray__":"...","dtype":"float64","shape":[63]}}},"id":"9db257fc-6ef1-4081-b2ad-6a4de3ceb5cf","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"population","transform":{"id":"df06db09-64cf-47f2-816a-975bd8614b05","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b8f7b4a9-298d-44fe-ae6e-54b2d1281e4c","type":"Circle"},{"attributes":{"data_source":{"id":"9db257fc-6ef1-4081-b2ad-6a4de3ceb5cf","type":"ColumnDataSource"},"glyph":{"id":"792224d6-d93b-4381-9dbd-2b9087e13054","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b8f7b4a9-298d-44fe-ae6e-54b2d1281e4c","type":"Circle"},"selection_glyph":null,"view":{"id":"7875af29-18bd-48ad-b8b3-f21a0467ce8d","type":"CDSView"}},"id":"eb916983-6bba-4cfb-8350-8b73374ec260","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"teal"},"line_alpha":{"value":0.6},"line_color":{"value":"teal"},"size":{"field":"population","transform":{"id":"df06db09-64cf-47f2-816a-975bd8614b05","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"792224d6-d93b-4381-9dbd-2b9087e13054","type":"Circle"},{"attributes":{"formatter":{"id":"a5aa1219-9a8b-4b3d-bd11-c80e012ce646","type":"BasicTickFormatter"},"plot":{"id":"a9ac0c1a-c7d3-4b5d-87cb-ae7af0223eb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"f359bf4d-ebe0-4de8-95d5-56166ce1bbfb","type":"BasicTicker"}},"id":"ef069a2c-518f-4c1a-989b-d13e7f0032f5","type":"LinearAxis"},{"attributes":{"data":null,"x":[69539,1262645000],"y":[5,50]},"id":"df06db09-64cf-47f2-816a-975bd8614b05","type":"LinearInterpolator"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f43d9379-bae1-4bb6-baed-8a8508317be2","type":"HoverTool"}]},"id":"e5d6d7eb-63f1-4113-b315-c51558af3c3c","type":"Toolbar"},{"attributes":{"formatter":{"id":"7832ce54-bd24-4f0c-8892-5bf6f9fe3cab","type":"BasicTickFormatter"},"plot":{"id":"a9ac0c1a-c7d3-4b5d-87cb-ae7af0223eb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3cf3bd7-a05e-45d6-903e-345724a4a55e","type":"BasicTicker"}},"id":"18c6e76e-03c2-4771-a10f-e12647de715f","typ ...

# %%
# countries colored by region 
from bokeh.models import LinearInterpolator, CategoricalColorMapper
from bokeh.palettes import Spectral6

hover = HoverTool(tooltips = [('Country','@country'),('Population','@pop'),])

region_values = list(gapminder.cluster.unique())
print (region_values)
region_values = [str(r) for r in region_values ]

population = gapminder.loc[gapminder['year'] == 2000]['pop']
region = gapminder.loc[gapminder['year'] == 2000]['cluster']

size_mapper = LinearInterpolator(x = [population.min(), population.max()], y = [5,50])
color_mapper = CategoricalColorMapper(factors = region_values ,palette = Spectral6)

source = ColumnDataSource(dict(x=fertility,y=life, country = country, population = population, region = region))

grph = figure(tools = [hover], height = 300, title = 'Fertility and Life Expectancy')

#can add transparancy with alpha =0.6
grph.circle(x = 'x', y = 'y', color ={'field' : 'region', 'transform' :color_mapper},
            size ={'field' : 'population', 'transform' :size_mapper}, 
            alpha =0.6, 
            source =source) 

show(grph)
# Out:
# [0, 3, 4, 1, 5, 2]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="73543730-ec41-4739-b486-96c180ffd032"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("73543730-ec41-4739-b486-96c180ffd032");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("73543730-ec41-4739-b486-96c180ffd032");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '73543730-ec41-4739-b486-96c180ffd032' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bc6ed5a3-6366-4e11-842c-0f815f075c03":{"roots":{"references":[{"attributes":{},"id":"d4d05b41-ea24-409f-88a3-4164428f5568","type":"BasicTickFormatter"},{"attributes":{"data":null,"x":[69539,1262645000],"y":[5,50]},"id":"e2fbece4-5a75-4242-b17e-1f8c368ebd92","type":"LinearInterpolator"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"population","transform":{"id":"e2fbece4-5a75-4242-b17e-1f8c368ebd92","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"